# %% [markdown]
# #                                                 Capstone Project - The Battle of the Neighborhoods

# %% [markdown]
# ## Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Table of contents

# %% [markdown]
# 1. Introduction: Business Problem
# 2. Foursquare API Explore Function
# 3. Data
# 4. Methodology
# 5. Analysis
# 6. Results and Discussion
# 7. Conclusion

# %% [markdown]
# ## Introduction: Business Problem

# %% [markdown]
# In this project we will try to find an optimal location for opening a restraunt in Mumbai,India near very famous Taj Hotel located near 'Gateway of India'. Our sole sole objective is tofind location that is surrounded by least number of restaraunts and is nearest to Taj hotel that is a hertiage,five-star,luxury hotel situated next to 'Gateway of India' an arch monument which attracts almost 6million tourists per year,making it the 30th most visited location worldwide. Since there are lots of restaurants in this location we will try to detect locations that are not already crowded with restaurants. We are also particularly interested in areas with no restaurants in vicinity. We would also prefer locations as close to Taj or Gateway of India as possible, assuming that first two conditions are met.
#
# We will use our data science powers to generate a few most promissing neighborhoods based on this criteria. Advantages of each area will then be clearly expressed so that best possible final location can be chosen by stakeholders.We will use our data science powers to generate a few most promissing neighborhoods based on this criteria. Advantages of each area will then be clearly expressed so that best possible final location can be chosen by stakeholders.

# %% [markdown]
# ### Data

# %% [markdown]
# Based on definition of our problem, factors that will influence our decission are:
#
# 1. number of existing restaurants in the neighborhood (any type of restaurant)
# 2. distance of neighborhood from Taj hotel
#
# We decided to use regularly spaced grid of locations, centered around Taj hotel, to define our neighborhoods.
#
# Following data sources will be needed to extract/generate the required information:
#
# 1. centers of candidate areas will be generated algorithmically and approximate addresses of centers of those areas will be obtained using Google Maps API reverse geocoding
# 2. number of restaurants and their type and location in every neighborhood will be obtained using Foursquare API
# 3. coordinate of Taj hotel will be obtained using Google Maps API geocoding.
#
# Firstly we will do a general exploration using foursquare Api search query of food.

# %% [markdown]
# ## Import necessary libraries

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/4f/86/1ab30184cb60bc2b95deffe2bd86b8ddbab65a4fac9f7313c278c6e8d049/folium-0.9.1-py2.py3-none-any.whl (91kB)
#      |████████████████████████████████| 92kB 201kB/s eta 0:00:01
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/63/36/1c93318e9653f4e414a2e0c3b98fc898b4970e939afeedeee6075dd3b703/branca-0.3.1-py3-none-any.whl
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from branca>=0.3.0->folium) (1.12.0)
# Installing collected packages: branca, folium
# Successfully installed branca-0.3.1 folium-0.9.1

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %% [markdown]
# ## Foursquare Credentials and Version

# %%
CLIENT_ID = 'JUTCRLID0YQPCJTFZFWR2H4ZJAY4U4FPI1UWKGLLZQWCVYSO' 
CLIENT_SECRET = 'POXMM5P2BIKB015Z0MJSQAANPXBVGFXL4GIMGQAHDKK2N01O' 
VERSION = '20180604'
LIMIT = 100
radius=4000
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: JUTCRLID0YQPCJTFZFWR2H4ZJAY4U4FPI1UWKGLLZQWCVYSO
# CLIENT_SECRET:POXMM5P2BIKB015Z0MJSQAANPXBVGFXL4GIMGQAHDKK2N01O

# %% [markdown]
# To get co-ordinates of taj ,mumbai

# %%
address = 'Taj,mumbai,India'


geolocator = Nominatim(user_agent="mumbai_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 18.921778 72.8332848316978

# %% [markdown]
# Since we are interested about setting up a restraunt we will use foursquare Api to run a search quary of'food'

# %%
search_query = 'food'
print(search_query + ' .... OK!')
# Out:
# food .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=JUTCRLID0YQPCJTFZFWR2H4ZJAY4U4FPI1UWKGLLZQWCVYSO&client_secret=POXMM5P2BIKB015Z0MJSQAANPXBVGFXL4GIMGQAHDKK2N01O&ll=18.921778,72.8332848316978&v=20180604&query=food&radius=4000&limit=100'

# %% [markdown]
# Get data in form of json file

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d3815b60d2be7002c827ea4'},
#  'response': {'venues': [{'id': '4d00fa9d1fcef04db587cdb9',
#     'name': 'Food Inn',
#     'location': {'address': 'Colaba Causeway',
#      'crossStreet': 'Opp. Colaba Police Station',
#      'lat': 18.922201885707175,
#      'lng': 72.83132552885246,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.922201885707175,
#        'lng': 72.83132552885246}],
#      'distance': 211,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Colaba Causeway (Opp. Colaba Police Station)',
#       'Mumbai',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '51cbcbbc498e0628b081ec42',
#     'name': 'Food Matters India Pvt Ltd, Akbar House',
#     'location': {'lat': 18.922996508345086,
#      'lng': 72.83224380626754,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.922996508345086,
#        'lng': 72.83224380626754}],
#      'distance': 174,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '4d73d097ff6ba35d5431818a',
#     'name': 'Food Plaza',
#     'location': {'address': 'Colaba',
#      'crossStreet': 'Near strand cinema',
#      'lat': 18.917078419813787,
#      'lng': 72.82997197121956,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.917078419813787,
#        'lng': 72.82997197121956}],
#      'distance': 628,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Colaba (Near strand cinema)',
#       'Mumbai',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '53e79b49498e59eb2d6d4f1c',
#     'name': 'Apna Fast Food Centre',
#     'location': {'address': '4/C, 29 A Kamal Mansion, H.N.A.',
#      'crossStreet': 'Azmi Marg, Colaba',
#      'lat': 18.918905634660955,
#      'lng': 72.8303758705811,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.918905634660955,
#        'lng': 72.8303758705811}],
#      'distance': 442,
#      'postalCode': '400005',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['4/C, 29 A Kamal Mansion, H.N.A. (Azmi Marg, Colaba)',
#       'Mumbai 400005',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '5501522b498eed335750dcc5',
#     'name': 'Foods on Wheels - Food Delivery in Trains',
#     'location': {'lat': 18.929528411141078,
#      'lng': 72.83063292503357,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.929528411141078,
#        'lng': 72.83063292503357}],
#      'distance': 906,
#      'postalCode': '400005',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Mumbai 400005', 'Mahārāshtra', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '5350dc5e498eca02db44b207',
#     'name': 'Food Court',
#     'location': {'address': 'Inox',
#      'lat': 18.923886,
#      'lng': 72.824297,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.923886,
#        'lng': 72.824297}],
#      'distance': 975,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['Inox', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '4dde5caed16415421840ebf8',
#     'name': 'H Parmesha Fast Food Corner',
#     'location': {'address': 'Near BSE',
#      'lat': 18.930392315607495,
#      'lng': 72.83354934229565,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.930392315607495,
#        'lng': 72.83354934229565}],
#      'distance': 959,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Near BSE', 'Mumbai', 'Mahārāshtra', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '5783558c498e7f1882e7977f',
#     'name': 'Great western fast food',
#     'location': {'lat': 18.928035,
#      'lng': 72.83308,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.928035,
#        'lng': 72.83308}],
#      'distance': 696,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '4cfe22077f2db1f745873bd4',
#     'name': 'Food for Thought',
#     'location': {'address': '@Kitabkhana, Somaiya Bhavan',
#      'crossStreet': '45/47  Mahatma Gandhi Road, Fort',
#      'lat': 18.932030548104755,
#      'lng': 72.83166719005116,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.932030548104755,
#        'lng': 72.83166719005116}],
#      'distance': 1153,
#      'postalCode': '400001',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['@Kitabkhana, Somaiya Bhavan (45/47  Mahatma Gandhi Road, Fort)',
#       'Mumbai 400001',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '33013527'},
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '4f8e5f08e4b084124a75f038',
#     'name': 'roshni food point',
#     'location': {'address': '91 Janmabhoomi Marg,',
#      'crossStreet': 'Off D.N Road near parsi agairy',
#      'lat': 18.928314664508974,
#      'lng': 72.83276463313268,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.928314664508974,
#        'lng': 72.83276463313268}],
#      'distance': 729,
#      'postalCode': '400001',
#      'cc': 'IN',
#      'city': 'Fort',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['91 Janmabhoomi Marg, (Off D.N Road near parsi agairy)',
#       'Fort 400001',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '4ecdebc3722e01c57f8760c5',
#     'name': 'Food Fest',
#     'location': {'lat': 18.92995834350586,
#      'lng': 72.82711029052734,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.92995834350586,
#        'lng': 72.82711029052734}],
#      'distance': 1118,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '4ecdea912c5bc35054230bda',
#     'name': 'Food King',
#     'location': {'lat': 18.92995834350586,
#      'lng': 72.82711029052734,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.92995834350586,
#        'lng': 72.82711029052734}],
#      'distance': 1118,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d1d3941735',
#       'name': 'Vegetarian / Vegan Restaurant',
#       'pluralName': 'Vegetarian / Vegan Restaurants',
#       'shortName': 'Vegetarian / Vegan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '4b84d51ef964a520264531e3',
#     'name': 'Grub Corner, parsi food',
#     'location': {'address': 'Ash lane',
#      'crossStreet': 'Flora fountain, fort',
#      'lat': 18.93042148575897,
#      'lng': 72.83194184303284,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.93042148575897,
#        'lng': 72.83194184303284}],
#      'distance': 972,
#      'postalCode': '400001',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Ash lane (Flora fountain, fort)',
#       'Mumbai 400001',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1c7941735',
#       'name': 'Snack Place',
#       'pluralName': 'Snack Places',
#       'shortName': 'Snacks',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '5a06b0a77269fe0a9a40b515',
#     'name': 'Food supplements online',
#     'location': {'address': 'Mumbai Maharashtra 400078 India',
#      'lat': 18.933161571267057,
#      'lng': 72.83457040786743,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.933161571267057,
#        'lng': 72.83457040786743}],
#      'distance': 1274,
#      'postalCode': '400078',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Mumbai Maharashtra 400078 India',
#       'Mumbai 400078',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '50aa9e744b90af0d42d5de0e',
#       'name': 'Health Food Store',
#       'pluralName': 'Health Food Stores',
#       'shortName': 'Health Food Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '57c1aee3498efd85bedc3ead',
#     'name': 'World StrEAT Food',
#     'location': {'lat': 18.924619,
#      'lng': 72.824361,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.924619,
#        'lng': 72.824361}],
#      'distance': 991,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '4e3ff3f8e4cdab9b93630774',
#     'name': 'Subkuchh Food Plaza',
#     'location': {'address': 'Churchgate Station',
#      'lat': 18.93260831,
#      'lng': 72.83565297,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.93260831,
#        'lng': 72.83565297}],
#      'distance': 1231,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Churchgate Station',
#       'Mumbai',
#       'Mahārāshtra',
#       'India']},
#     'categories': [],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '58b5af4776b8b2472376daf1',
#     'name': 'Street Food Express',
#     'location': {'lat': 18.914036,
#      'lng': 72.8244,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.914036,
#        'lng': 72.8244}],
#      'distance': 1272,
#      'postalCode': '400005',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Mumbai 400005', 'Mahārāshtra', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '4eeceb26e300215592df7587',
#     'name': 'Apna Fast Food Centre',
#     'location': {'address': 'Near Radio Club',
#      'lat': 18.96497912245656,
#      'lng': 72.83390130661454,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.96497912245656,
#        'lng': 72.83390130661454}],
#      'distance': 4809,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['Near Radio Club', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '505c274ee4b00e3799611d83',
#     'name': 'priyanka fast food',
#     'location': {'lat': 18.929649353027344,
#      'lng': 72.82246398925781,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.929649353027344,
#        'lng': 72.82246398925781}],
#      'distance': 1437,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '52da1fb711d2bf36822c6a30',
#     'name': 'IRCTC food plaza churchgate',
#     'location': {'lat': 18.93316,
#      'lng': 72.826581,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.93316,
#        'lng': 72.826581}],
#      'distance': 1450,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '53803a2d498e5da6507c877d',
#     'name': 'BBC Good Food Magazine',
#     'location': {'lat': 18.941950696112205,
#      'lng': 72.83445059890043,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.941950696112205,
#        'lng': 72.83445059890043}],
#      'distance': 2248,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '5224a66b11d24fd41a2d141a',
#     'name': 'American Fast Food',
#     'location': {'crossStreet': 'Cuffe Parade',
#      'lat': 18.914618,
#      'lng': 72.819072,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.914618,
#        'lng': 72.819072}],
#      'distance': 1695,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Cuffe Parade', 'Mumbai', 'Mahārāshtra', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '538062ce498e59fb622d4be4',
#     'name': 'World Food Centre',
#     'location': {'address': 'Across World Trade Centre',
#      'crossStreet': 'Cuffe Parade',
#      'lat': 18.915857315063477,
#      'lng': 72.8171615600586,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.915857315063477,
#        'lng': 72.8171615600586}],
#      'distance': 1821,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Across World Trade Centre (Cuffe Parade)',
#       'Mumbai',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '510e7580e4b0bb3c67429511',
#     'name': 'Manoj Kumar Gupta American Fast Food',
#     'location': {'address': 'World Trade Center',
#      'crossStreet': 'Cuffe Parade',
#      'lat': 18.914606089538914,
#      'lng': 72.81892217958233,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.914606089538914,
#        'lng': 72.81892217958233}],
#      'distance': 1710,
#      'postalCode': '400005',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['World Trade Center (Cuffe Parade)',
#       'Mumbai 400005',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '4e6a0ba5483bf2d9e609c9ac',
#     'name': 'Times Food Court',
#     'location': {'lat': 18.941978433513256,
#      'lng': 72.83464944513254,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.941978433513256,
#        'lng': 72.83464944513254}],
#      'distance': 2253,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Mumbai', 'Mahārāshtra', 'India']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '4bab7819f964a520b6ab3ae3',
#     'name': 'Status',
#     'location': {'address': 'Regent Chambers, Jamnalal Bajaj Rd,',
#      'crossStreet': 'Jamnalal Bajaj Rd,',
#      'lat': 18.924562,
#      'lng': 72.821526,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.924562,
#        'lng': 72.821526}],
#      'distance': 1276,
#      'postalCode': '400021',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Regent Chambers, Jamnalal Bajaj Rd, (Jamnalal Bajaj Rd,)',
#       'Mumbai 400021',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '5097a524498ecb7e5608a872',
#     'name': 'Refresh Food Plaza, CST',
#     'location': {'lat': 18.940723147463906,
#      'lng': 72.83540147670111,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.940723147463906,
#        'lng': 72.83540147670111}],
#      'distance': 2120,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d1c7941735',
#       'name': 'Snack Place',
#       'pluralName': 'Snack Places',
#       'shortName': 'Snacks',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '51bc6c32498ef5b71a5d7d9b',
#     'name': "Bindal's Madhyantar fast food",
#     'location': {'address': 'Bombay Hospital',
#      'lat': 18.941913,
#      'lng': 72.82645,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.941913,
#        'lng': 72.82645}],
#      'distance': 2354,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Bombay Hospital',
#       'Mumbai',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1d3941735',
#       'name': 'Vegetarian / Vegan Restaurant',
#       'pluralName': 'Vegetarian / Vegan Restaurants',
#       'shortName': 'Vegetarian / Vegan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '4bc6c48704e8b713f57f362d',
#     'name': 'Hotel Deluxe',
#     'location': {'address': 'Pitha Street',
#      'crossStreet': 'Fort',
#      'lat': 18.93391483135239,
#      'lng': 72.83320482251608,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.93391483135239,
#        'lng': 72.83320482251608}],
#      'distance': 1351,
#      'postalCode': '400001',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Pitha Street (Fort)',
#       'Mumbai 400001',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '4f4121bae4b0f6acbbec8786',
#     'name': 'sai sagar fast food',
#     'location': {'lat': 18.943345432697495,
#      'lng': 72.83502066516891,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.943345432697495,
#        'lng': 72.83502066516891}],
#      'distance': 2407,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '53b04d48498e3bbe35010abb',
#     'name': 'food factory',
#     'location': {'address': 'Charni Road',
#      'lat': 18.955806732177734,
#      'lng': 72.81903076171875,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.955806732177734,
#        'lng': 72.81903076171875}],
#      'distance': 4074,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['Charni Road', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '5305c2d5498eef854aa1fe4b',
#     'name': 's.dsouza goan food',
#     'location': {'lat': 18.94533920288086,
#      'lng': 72.82657623291016,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.94533920288086,
#        'lng': 72.82657623291016}],
#      'distance': 2716,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '5416b1e3498ec452903834d8',
#     'name': 'grant house sea food resturant',
#     'location': {'lat': 18.94634155569771,
#      'lng': 72.83469755188712,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.94634155569771,
#        'lng': 72.83469755188712}],
#      'distance': 2738,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d1ce941735',
#       'name': 'Seafood Restaurant',
#       'pluralName': 'Seafood Restaurants',
#       'shortName': 'Seafood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '4b0587dbf964a5206ba422e3',
#     'name': "Ayub's",
#     'location': {'address': '43, Dr. V B Gandhi Marg',
#      'crossStreet': 'Near Rhytm House, Fort',
#      'lat': 18.9283825895931,
#      'lng': 72.83295065400509,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.9283825895931,
#        'lng': 72.83295065400509}],
#      'distance': 736,
#      'postalCode': '400023',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['43, Dr. V B Gandhi Marg (Near Rhytm House, Fort)',
#       'Mumbai 400023',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '50b51b51e4b0e8dbde2d2665',
#     'name': 'Annapurna food center',
#     'location': {'address': 'Kalbadevi',
#      'lat': 18.95011542398918,
#      'lng': 72.82867948877055,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.95011542398918,
#        'lng': 72.82867948877055}],
#      'distance': 3191,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['Kalbadevi', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '50c217aae4b08e7068b0428c',
#     'name': 'Amar Fast Food',
#     'location': {'lat': 18.9545625634834,
#      'lng': 72.81479641132644,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.9545625634834,
#        'lng': 72.81479641132644}],
#      'distance': 4136,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '50e04f19e4b0f2167b240220',
#     'name': 'Colombo Chinese & Fast Food',
#     'location': {'address': 'Chira Bazar',
#      'lat': 18.95097,
#      'lng': 72.823498,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.95097,
#        'lng': 72.823498}],
#      'distance': 3409,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Chira Bazar', 'Mumbai', 'Mahārāshtra', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '4deb24ded4c00071b836b8ee',
#     'name': 'Foodiez Express',
#     'location': {'address': '59, Nariman House',
#      'lat': 18.938248,
#      'lng': 72.835727,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.938248,
#        'lng': 72.835727}],
#      'distance': 1851,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['59, Nariman House',
#       'Mumbai',
#       'Mahārāshtra',
#       'India']},
#     'categories': [],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '5b0588786f0aa2002ce516b0',
#     'name': 'Marhaba Fast Food Center',
#     'location': {'lat': 18.954979,
#      'lng': 72.83341,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.954979,
#        'lng': 72.83341}],
#      'distance': 3695,
#      'postalCode': '400003',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Mumbai 400003', 'Mahārāshtra', 'India']},
#     'categories': [{'id': '54135bf5e4b08f3d2429dff4',
#       'name': 'Mughlai Restaurant',
#       'pluralName': 'Mughlai Restaurants',
#       'shortName': 'Mughlai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '51e4185d498e8fc6bfbc75cc',
#     'name': 'Marahaba Fast Food Center',
#     'location': {'lat': 18.954944610595703,
#      'lng': 72.83335876464844,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.954944610595703,
#        'lng': 72.83335876464844}],
#      'distance': 3692,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '502fd4cfe4b0e2ee602403f4',
#     'name': 'humsyd ayaan fast food',
#     'location': {'lat': 18.955280763583275,
#      'lng': 72.83374551919181,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.955280763583275,
#        'lng': 72.83374551919181}],
#      'distance': 3729,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '4f17f838e4b0e5837ba30a0b',
#     'name': 'Yadav Fast Food Center',
#     'location': {'lat': 18.95386159555178,
#      'lng': 72.8206590206532,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.95386159555178,
#        'lng': 72.8206590206532}],
#      'distance': 3810,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '51330ec0e4b0ef4e16f6c326',
#     'name': 'Subkuchh Food Plaza',
#     'location': {'address': 'Churchgate',
#      'lat': 18.955866493309095,
#      'lng': 72.83566112058648,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.955866493309095,
#        'lng': 72.83566112058648}],
#      'distance': 3802,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Churchgate', 'Mumbai', 'Mahārāshtra', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '551a7176498e036e7ad2053f',
#     'name': 'Sevim Sultan Fast Food',
#     'location': {'address': 'D',
#      'lat': 18.957990646362305,
#      'lng': 72.840087890625,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.957990646362305,
#        'lng': 72.840087890625}],
#      'distance': 4094,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['D', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d16b941735',
#       'name': 'Brazilian Restaurant',
#       'pluralName': 'Brazilian Restaurants',
#       'shortName': 'Brazilian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '56ceaf2c498eddd77fb58a2d',
#     'name': 'FoodAbhi',
#     'location': {'crossStreet': 'Dr. C H Street, Marine lines - E',
#      'lat': 18.943390826634825,
#      'lng': 72.82991409301758,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.943390826634825,
#        'lng': 72.82991409301758}],
#      'distance': 2431,
#      'postalCode': '400002',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Dr. C H Street, Marine lines - E',
#       'Mumbai 400002',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '4f13022fe4b0253d4e504eff',
#     'name': 'Hamza Fast Food',
#     'location': {'lat': 18.959710562143922,
#      'lng': 72.83207801054373,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.959710562143922,
#        'lng': 72.83207801054373}],
#      'distance': 4224,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '5162d59ee4b0e6bf96e11cf6',
#     'name': 'Jilani Fast Food',
#     'location': {'crossStreet': 'Bori Mohalla',
#      'lat': 18.95993295276538,
#      'lng': 72.83105095802122,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.95993295276538,
#        'lng': 72.83105095802122}],
#      'distance': 4253,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Bori Mohalla', 'Mumbai', 'Mahārāshtra', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '4dd57682fa76ad96d0f4d44b',
#     'name': 'Marhaba Mughal Fast Food',
#     'location': {'lat': 18.961754,
#      'lng': 72.831569,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.961754,
#        'lng': 72.831569}],
#      'distance': 4453,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Mumbai', 'Mahārāshtra', 'India']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '51603078e4b0878cf3aee814',
#     'name': "Mumbai's Foodie Corner",
#     'location': {'address': 'Bazaar gate street',
#      'lat': 18.934507575744806,
#      'lng': 72.83548225482843,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.934507575744806,
#        'lng': 72.83548225482843}],
#      'distance': 1435,
#      'postalCode': '400001',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Bazaar gate street',
#       'Mumbai 400001',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1c7941735',
#       'name': 'Snack Place',
#       'pluralName': 'Snack Places',
#       'shortName': 'Snacks',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False},
#    {'id': '59104f5ba423623a3e770fbd',
#     'name': 'Parag Milk Foods Ltd',
#     'location': {'address': '10/20th Floor, Nirmal Bldg, Next To Inox (cr2), Nariman Point.',
#      'lat': 18.927331,
#      'lng': 72.822057,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.927331,
#        'lng': 72.822057}],
#      'distance': 1334,
#      'postalCode': '400021',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['10/20th Floor, Nirmal Bldg, Next To Inox (cr2), Nariman Point.',
#       'Mumbai 400021',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563956662',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 1  [{'id': '4bf58dd8d48988d130941735', 'name': 'B...    False
# 2  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 3  [{'id': '4bf58dd8d48988d1df931735', 'name': 'B...    False
# 4  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
#
#                          id                 location.address location.cc  \
# 0  4d00fa9d1fcef04db587cdb9                  Colaba Causeway          IN
# 1  51cbcbbc498e0628b081ec42                              NaN          IN
# 2  4d73d097ff6ba35d5431818a                           Colaba          IN
# 3  53e79b49498e59eb2d6d4f1c  4/C, 29 A Kamal Mansion, H.N.A.          IN
# 4  5501522b498eed335750dcc5                              NaN          IN
#
#   location.city location.country        location.crossStreet  \
# 0        Mumbai            India  Opp. Colaba Police Station
# 1           NaN            India                         NaN
# 2        Mumbai            India          Near strand cinema
# 3        Mumbai            India           Azmi Marg, Colaba
# 4        Mumbai            India                         NaN
#
#    location.distance                          location.formattedAddress  \
# 0                211  [Colaba Causeway (Opp. Colaba Police Station),...
# 1                174                                            [India]
# 2                628  [Colaba (Near strand cinema), Mumbai, Mahārāsh...
# 3                442  [4/C, 29 A Kamal Mansion, H.N.A. (Azmi Marg, C...
# 4                906                [Mumbai 400005, Mahārāshtra, India]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 18.92220188570717...     18.922202
# 1  [{'label': 'display', 'lat': 18.92299650834508...     18.922997
# 2  [{'label': 'display', 'lat': 18.91707841981378...     18.917078
# 3  [{'label': 'display', 'lat': 18.91890563466095...     18.918906
# 4  [{'label': 'display', 'lat': 18.92952841114107...     18.929528
#
#    location.lng location.postalCode location.state  \
# 0     72.831326                 NaN    Mahārāshtra
# 1     72.832244                 NaN            NaN
# 2     72.829972                 NaN    Mahārāshtra
# 3     72.830376              400005    Mahārāshtra
# 4     72.830633              400005    Mahārāshtra
#
#                                         name    referralId venuePage.id
# 0                                   Food Inn  v-1563956662          NaN
# 1    Food Matters India Pvt Ltd, Akbar House  v-1563956662          NaN
# 2                                 Food Plaza  v-1563956662          NaN
# 3                      Apna Fast Food Centre  v-1563956662          NaN
# 4  Foods on Wheels - Food Delivery in Trains  v-1563956662          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                                         name            categories  \
# 0                                   Food Inn     Indian Restaurant
# 1    Food Matters India Pvt Ltd, Akbar House              Building
# 2                                 Food Plaza            Restaurant
# 3                      Apna Fast Food Centre             BBQ Joint
# 4  Foods on Wheels - Food Delivery in Trains  Fast Food Restaurant
# 5                                 Food Court  Fast Food Restaurant
# 6                H Parmesha Fast Food Corner  Fast Food Restaurant
# 7                    Great western fast food        Sandwich Place
# 8                           Food for Thought                  Café
# 9                          roshni food point     Indian Restaurant
#
#                            address  cc    city country  \
# 0                  Colaba Causeway  IN  Mumbai   India
# 1                              NaN  IN     NaN   India
# 2                           Colaba  IN  Mumbai   India
# 3  4/C, 29 A Kamal Mansion, H.N.A.  IN  Mumbai   India
# 4                              NaN  IN  Mumbai   India
# 5                             Inox  IN     NaN   India
# 6                         Near BSE  IN  Mumbai   India
# 7                              NaN  IN     NaN   India
# 8      @Kitabkhana, Somaiya Bhavan  IN  Mumbai   India
# 9             91 Janmabhoomi Marg,  IN    Fort   India
#
#                         crossStreet  distance  \
# 0        Opp. Colaba Police Station       211
# 1                               NaN       174
# 2                Near strand cinema       628
# 3                 Azmi Marg, Colaba       442
# 4                               NaN       906
# 5                               NaN       975
# 6                               NaN       959
# 7                               NaN       696
# 8  45/47  Mahatma Gandhi Road, Fort      1153
# 9    Off D.N Road near parsi agairy       729
#
#                                     formattedAddress  \
# 0  [Colaba Causeway (Opp. Colaba Police Station),...
# 1                                            [India]
# 2  [Colaba (Near strand cinema), Mumbai, Mahārāsh...
# 3  [4/C, 29 A Kamal Mansion, H.N.A. (Azmi Marg, C...
# 4                [Mumbai 400005, Mahārāshtra, India]
# 5                                      [Inox, India]
# 6             [Near BSE, Mumbai, Mahārāshtra, India]
# 7                                            [India]
# 8  [@Kitabkhana, Somaiya Bhavan (45/47  Mahatma G...
# 9  [91 Janmabhoomi Marg, (Off D.N Road near parsi...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 18.92220188570717...  18.922202  72.831326
# 1  [{'label': 'display', 'lat': 18.92299650834508...  18.922997  72.832244
# 2  [{'label': 'display', 'lat': 18.91707841981378...  18.917078  72.829972
# 3  [{'label': 'display', 'lat': 18.91890563466095...  18.918906  72.830376
# 4  [{'label': 'display', 'lat': 18.92952841114107...  18.929528  72.830633
# 5  [{'label': 'display', 'lat': 18.923886, 'lng':...  18.923886  72.824297
# 6  [{'label': 'display', 'lat': 18.93039231560749...  18.930392  72.833549
# 7  [{'label': 'display', 'lat': 18.928035, 'lng':...  18.928035  72.833080
# 8  [{'label': 'display', 'lat': 18.93203054810475...  18.932031  72.831667
# 9  [{'label': 'display', 'lat': 18.92831466450897...  18.928315  72.832765
#
#   postalCode        state                        id
# 0        NaN  Mahārāshtra  4d00fa9d1fcef04db587cdb9
# 1        NaN          NaN  51cbcbbc498e0628b081ec42
# 2        NaN  Mahārāshtra  4d73d097ff6ba35d5431818a
# 3     400005  Mahārāshtra  53e79b49498e59eb2d6d4f1c
# 4     400005  Mahārāshtra  5501522b498eed335750dcc5
# 5        NaN          NaN  5350dc5e498eca02db44b207
# 6        NaN  Mahārāshtra  4dde5caed16415421840ebf8
# 7        NaN          NaN  5783558c498e7f1882e7977f
# 8     400001  Mahārāshtra  4cfe22077f2db1f745873bd4
# 9     400001  Mahārāshtra  4f8e5f08e4b084124a75f038

# %%
dataframe_filtered.shape
# Out:
# (50, 15)

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Taj

# add a red circle marker to represent the Taj
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Taj',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=JUTCRLID0YQPCJTFZFWR2H4ZJAY4U4FPI1UWKGLLZQWCVYSO&client_secret=POXMM5P2BIKB015Z0MJSQAANPXBVGFXL4GIMGQAHDKK2N01O&ll=18.921778,72.8332848316978&v=20180604&radius=4000&limit=100'

# %% [markdown]
# ## Get details of venues near Taj (General Exploration)

# %%
import requests

# %%
results = requests.get(url).json()

# %% [markdown]
# Get relevant part of JSON

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4b0587caf964a520f1a122e3',
#   'name': 'Taj Mahal Palace & Tower',
#   'location': {'address': 'Apollo Bunder',
#    'crossStreet': 'P. Jetha Singh Ramchandani Marg',
#    'lat': 18.92230601080199,
#    'lng': 72.83357809321173,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 18.92230601080199,
#      'lng': 72.83357809321173}],
#    'distance': 66,
#    'postalCode': '400001',
#    'cc': 'IN',
#    'city': 'Mumbai',
#    'state': 'Mahārāshtra',
#    'country': 'India',
#    'formattedAddress': ['Apollo Bunder (P. Jetha Singh Ramchandani Marg)',
#     'Mumbai 400001',
#     'Mahārāshtra',
#     'India']},
#   'categories': [{'id': '4bf58dd8d48988d1fa931735',
#     'name': 'Hotel',
#     'pluralName': 'Hotels',
#     'shortName': 'Hotel',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-4b0587caf964a520f1a122e3-0'}

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                                  name           categories  \
# 0            Taj Mahal Palace & Tower                Hotel
# 1  Sea Lounge, Taj Mahal Palace Hotel               Lounge
# 2                 PizzaExpress Colaba          Pizza Place
# 3                       Café Mondegar                 Café
# 4                        Woodside Inn                  Pub
# 5                           Le15 Cafe                 Café
# 6                  Wasabi by Morimoto  Japanese Restaurant
# 7                    Gateway of India  Monument / Landmark
# 8                          Sabyasachi             Boutique
# 9                        Leopold Café                 Café
#
#                                      address  cc    city country  \
# 0                              Apollo Bunder  IN  Mumbai   India
# 1        Mahakavi Bhushan Rd., Apollo Bandar  IN  Mumbai   India
# 2                              Dhanraj Mahal  IN  Mumbai   India
# 3  Metro House, 5-A Shahid Bhagat Singh Road  IN  Mumbai   India
# 4    Indian Mercantile Mansion, Wodehouse Rd  IN  Mumbai   India
# 5                             Lansdowne Road  IN  Mumbai   India
# 6                in Taj Mahal Hotel & Palace  IN  Mumbai   India
# 7    Apollo Bandar, Off P J Ramchandani Marg  IN  Mumbai   India
# 8                                 Kala Ghoda  IN  Mumbai   India
# 9           Shahid Bhagat Singh Road, Colaba  IN  Mumbai   India
#
#                          crossStreet  distance  \
# 0    P. Jetha Singh Ramchandani Marg        66
# 1                                NaN        30
# 2                             Colaba       236
# 3                  Near Regal Cinema       298
# 4              opposite Regal Cinema       360
# 5                     Battery Street       222
# 6                                NaN        47
# 7  near the Taj Mahal Palace & Tower       167
# 8                                NaN       580
# 9              Nowroji Ferdonji Road       203
#
#                                     formattedAddress  \
# 0  [Apollo Bunder (P. Jetha Singh Ramchandani Mar...
# 1  [Mahakavi Bhushan Rd., Apollo Bandar, Mumbai 4...
# 2  [Dhanraj Mahal (Colaba), Mumbai 400001, Mahārā...
# 3  [Metro House, 5-A Shahid Bhagat Singh Road (Ne...
# 4  [Indian Mercantile Mansion, Wodehouse Rd (oppo...
# 5  [Lansdowne Road (Battery Street), Mumbai 40000...
# 6  [in Taj Mahal Hotel & Palace, Mumbai 400001, M...
# 7  [Apollo Bandar, Off P J Ramchandani Marg (near...
# 8           [Kala Ghoda, Mumbai, Mahārāshtra, India]
# 9  [Shahid Bhagat Singh Road, Colaba (Nowroji Fer...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 18.92230601080199...  18.922306  72.833578
# 1  [{'label': 'display', 'lat': 18.92150340821261...  18.921503  72.833298
# 2  [{'label': 'display', 'lat': 18.92389908404944...  18.923899  72.833452
# 3  [{'label': 'display', 'lat': 18.92421903757405...  18.924219  72.832106
# 4  [{'label': 'display', 'lat': 18.92475092153973...  18.924751  72.831930
# 5  [{'label': 'display', 'lat': 18.923709, 'lng':...  18.923709  72.832735
# 6  [{'label': 'display', 'lat': 18.92201185805479...  18.922012  72.833663
# 7  [{'label': 'display', 'lat': 18.921856, 'lng':...  18.921856  72.834877
# 8  [{'label': 'display', 'lat': 18.92698975318335...  18.926990  72.833185
# 9  [{'label': 'display', 'lat': 18.92282790125498...  18.922828  72.831709
#
#   neighborhood postalCode        state                        id
# 0          NaN     400001  Mahārāshtra  4b0587caf964a520f1a122e3
# 1          NaN     400001  Mahārāshtra  4c332ca13896e21e658be990
# 2          NaN     400001  Mahārāshtra  50caded2e4b06f07c9b15053
# 3          NaN     400039  Mahārāshtra  4b9c68ddf964a5209a6636e3
# 4          NaN    400 039  Mahārāshtra  4b0587cef964a5207ba222e3
# 5       Colaba     400005  Mahārāshtra  56b9ee80498edc99be627f0e
# 6          NaN     400001  Mahārāshtra  4b41e0cff964a520b8c925e3
# 7          NaN     400001  Mahārāshtra  4b0587d1f964a520cea222e3
# 8          NaN        NaN  Mahārāshtra  4e159ee718384368edd10486
# 9          NaN     400039  Mahārāshtra  4ce68ea5f1c6236a571f54f0

# %% [markdown]
# Since around 4km in radius Taj there many restaraunts so will try to find most optimal location for it. We would also prefer locations as close to Taj as possible.We will divide area around taj into grids upto 6km radius and try to find ares with least number of restraunts in those grids. Let's create latitude & longitude coordinates for centroids of our candidate neighborhoods. We will create a grid of cells covering our area of interest which is aprox. 12x12 killometers centered around Taj.
#
# Let's first find the latitude & longitude of Berlin city center, using specific, well known address and Google Maps geocoding API.

# %%
google_api_key='AIzaSyB8QdOk3UbmTiC4xoS4nGnM9ZvQYX9nVFk'

# %%
import requests

def get_coordinates(api_key, address, verbose=False):
    try:
        url = 'https://maps.googleapis.com/maps/api/geocode/json?key={}&address={}'.format(api_key, address)
        response = requests.get(url).json()
        if verbose:
            print('Google Maps API JSON result =>', response)
        results = response['results']
        geographical_data = results[0]['geometry']['location'] # get geographical coordinates
        lat = geographical_data['lat']
        lon = geographical_data['lng']
        return [lat, lon]
    except:
        return [None, None]
    
address = 'Taj hotel, Mumbai, India'
taj = get_coordinates(google_api_key, address)
print('Coordinate of {}: {}'.format(address, taj))
# Out:
# Coordinate of Taj hotel, Mumbai, India: [18.9217291, 72.8330309]

# %% [markdown]
# Let's create a hexagonal grid of cells: we offset every other row, and adjust vertical row spacing so that every cell center is equally distant from all it's neighbors.

# %%
# !pip install shapely
import shapely.geometry

# !pip install pyproj
import pyproj

import math

def lonlat_to_xy(lon, lat):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
    return xy[0], xy[1]

def xy_to_lonlat(x, y):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
    return lonlat[0], lonlat[1]

def calc_xy_distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    return math.sqrt(dx*dx + dy*dy)

print('Coordinate transformation check')
print('-------------------------------')
print('taj longitude={}, latitude={}'.format(taj[1], taj[0]))
x, y = lonlat_to_xy(taj[1], taj[0])
print('taj UTM X={}, Y={}'.format(x, y))
lo, la = xy_to_lonlat(x, y)
print('taj longitude={}, latitude={}'.format(lo, la))
# Out:
# Collecting shapely
#   Downloading https://files.pythonhosted.org/packages/38/b6/b53f19062afd49bb5abd049aeed36f13bf8d57ef8f3fa07a5203531a0252/Shapely-1.6.4.post2-cp36-cp36m-manylinux1_x86_64.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 234kB/s eta 0:00:01
# Installing collected packages: shapely
# Successfully installed shapely-1.6.4.post2
# Collecting pyproj
#   Downloading https://files.pythonhosted.org/packages/16/59/43869adef45ce4f1cf7d5c3aef1ea5d65d449050abdda5de7a2465c5729d/pyproj-2.2.1-cp36-cp36m-manylinux1_x86_64.whl (11.2MB)
#      |████████████████████████████████| 11.2MB 53.1MB/s eta 0:00:01
# Installing collected packages: pyproj
# Successfully installed pyproj-2.2.1
# Coordinate transformation check
# -------------------------------
# taj longitude=72.8330309, latitude=18.9217291
# taj UTM X=7525844.162540259, Y=3644093.2406203826
# taj longitude=72.83303089999986, latitude=18.921729099996877

# %%
taj_x, taj_y = lonlat_to_xy(taj[1], taj[0]) # taj in Cartesian coordinates

k = math.sqrt(3) / 2 # Vertical offset for hexagonal grid cells
x_min = taj_x - 6000
x_step = 600
y_min = taj_y - 6000 - (int(21/k)*k*600 - 12000)/2
y_step = 600 * k 

latitudes = []
longitudes = []
distances_from_center = []
xs = []
ys = []
for i in range(0, int(21/k)):
    y = y_min + i * y_step
    x_offset = 300 if i%2==0 else 0
    for j in range(0, 21):
        x = x_min + j * x_step + x_offset
        distance_from_center = calc_xy_distance(taj_x, taj_y, x, y)
        if (distance_from_center <= 6001):
            lon, lat = xy_to_lonlat(x, y)
            latitudes.append(lat)
            longitudes.append(lon)
            distances_from_center.append(distance_from_center)
            xs.append(x)
            ys.append(y)

print(len(latitudes), 'candidate neighborhood centers generated.')
# Out:
# 364 candidate neighborhood centers generated.

# %%
#!pip install folium

import folium

# %%
map_taj = folium.Map(location=taj, zoom_start=13)
folium.Marker(taj, popup='taj').add_to(map_taj)
for lat, lon in zip(latitudes, longitudes):
    folium.Circle([lat, lon], radius=300, color='blue', fill=False).add_to(map_taj)
map_taj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def get_address(api_key, latitude, longitude, verbose=False):
    try:
        url = 'https://maps.googleapis.com/maps/api/geocode/json?key={}&latlng={},{}'.format(api_key, latitude, longitude)
        response = requests.get(url).json()
        if verbose:
            print('Google Maps API JSON result =>', response)
        results = response['results']
        address = results[0]['formatted_address']
        return address
    except:
        return None

addr = get_address(google_api_key, taj[0], taj[1])
print('Reverse geocoding check')
print('-----------------------')
print('Address of [{}, {}] is: {}'.format(taj[0], taj[1], addr))
# Out:
# Reverse geocoding check
# -----------------------
# Address of [18.9217291, 72.8330309] is: None

# %%
print('Obtaining location addresses: ', end='')
addresses = []
for lat, lon in zip(latitudes, longitudes):
    address = get_address(google_api_key, lat, lon)
    if address is None:
        address = 'NO ADDRESS'
    address = address.replace(', Germany', '') # We don't need country part of address
    addresses.append(address)
    print(' .', end='')
print(' done.')
# Out:
# Obtaining location addresses:  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . done.

# %%
import pandas as pd

df_locations = pd.DataFrame({'Address': addresses,
                             'Latitude': latitudes,
                             'Longitude': longitudes,
                             'X': xs,
                             'Y': ys,
                             'Distance from center': distances_from_center})

df_locations.head(10)
# Out:
#       Address   Latitude  Longitude             X             Y  \
# 0  NO ADDRESS  18.898853  72.809006  7.524044e+06  3.638377e+06
# 1  NO ADDRESS  18.897358  72.812025  7.524644e+06  3.638377e+06
# 2  NO ADDRESS  18.895864  72.815044  7.525244e+06  3.638377e+06
# 3  NO ADDRESS  18.894369  72.818062  7.525844e+06  3.638377e+06
# 4  NO ADDRESS  18.892875  72.821080  7.526444e+06  3.638377e+06
# 5  NO ADDRESS  18.891381  72.824097  7.527044e+06  3.638377e+06
# 6  NO ADDRESS  18.889886  72.827115  7.527644e+06  3.638377e+06
# 7  NO ADDRESS  18.903583  72.805838  7.523144e+06  3.638897e+06
# 8  NO ADDRESS  18.902088  72.808857  7.523744e+06  3.638897e+06
# 9  NO ADDRESS  18.900594  72.811876  7.524344e+06  3.638897e+06
#
#    Distance from center
# 0           5992.495307
# 1           5840.376700
# 2           5747.173218
# 3           5715.767665
# 4           5747.173218
# 5           5840.376700
# 6           5992.495307
# 7           5855.766389
# 8           5604.462508
# 9           5408.326913

# %% [markdown]
# ## Foursquare

# %% [markdown]
# Now that we have our location candidates, let's use Foursquare API to get info on restaurants in each neighborhood.
#
# We're interested in venues in 'food' category, but only those that are proper restaurants - coffe shops, pizza places, bakeries etc. are not direct competitors so we don't care about those. So we will include in out list only venues that have 'restaurant' in category name.

# %%
df_locations.to_pickle('./locations.pkl')

# %%
food_category = '4d4b7105d754a06374d81259' # 'Root' category for all food-related venues

def is_restaurant(categories, specific_filter=None):
    restaurant_words = ['restaurant', 'diner', 'taverna', 'steakhouse']
    restaurant = False
    specific = False
    for c in categories:
        category_name = c[0].lower()
        category_id = c[1]
        for r in restaurant_words:
            if r in category_name:
                restaurant = True
        if 'fast food' in category_name:
            restaurant = False
        if not(specific_filter is None) and (category_id in specific_filter):
            specific = True
            restaurant = True
    return restaurant, specific

def get_categories(categories):
    return [(cat['name'], cat['id']) for cat in categories]

def format_address(location):
    address = ', '.join(location['formattedAddress'])
    address = address.replace(', India', '')
    return address

def get_venues_near_location(lat, lon, category, CLIENT_ID, CLIENT_SECRET, radius=500, limit=100):
    version = '20180724'
    url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&categoryId={}&radius={}&limit={}'.format(
        CLIENT_ID, CLIENT_SECRET, version, lat, lon, category, radius, limit)
    try:
        results = requests.get(url).json()['response']['groups'][0]['items']
        venues = [(item['venue']['id'],
                   item['venue']['name'],
                   get_categories(item['venue']['categories']),
                   (item['venue']['location']['lat'], item['venue']['location']['lng']),
                   format_address(item['venue']['location']),
                   item['venue']['location']['distance']) for item in results]        
    except:
        venues = []
    return venues

# %%
import pickle

def get_restaurants(lats, lons):
    restaurants = {}
    location_restaurants = []

    print('Obtaining venues around candidate locations:', end='')
    for lat, lon in zip(lats, lons):
        # Using radius=350 to meke sure we have overlaps/full coverage so we don't miss any restaurant (we're using dictionaries to remove any duplicates resulting from area overlaps)
        venues = get_venues_near_location(lat, lon, food_category, CLIENT_ID, CLIENT_SECRET, radius=350, limit=100)
        area_restaurants = []
        for venue in venues:
            venue_id = venue[0]
            venue_name = venue[1]
            venue_categories = venue[2]
            venue_latlon = venue[3]
            venue_address = venue[4]
            venue_distance = venue[5]
            is_res = is_restaurant(venue_categories)
            if is_res:
                x, y = lonlat_to_xy(venue_latlon[1], venue_latlon[0])
                restaurant = (venue_id, venue_name, venue_latlon[0], venue_latlon[1], venue_address, venue_distance, x, y)
                if venue_distance<=300:
                    area_restaurants.append(restaurant)
                restaurants[venue_id] = restaurant
        location_restaurants.append(area_restaurants)
        print(' .', end='')
    print(' done.')
    return restaurants, location_restaurants

# Try to load from local file system in case we did this before
restaurants = {}
location_restaurants = []
loaded = False
try:
    with open('restaurants_350.pkl', 'rb') as f:
        restaurants = pickle.load(f)
    with open('location_restaurants_350.pkl', 'rb') as f:
        location_restaurants = pickle.load(f)
    print('Restaurant data loaded.')
    loaded = True
except:
    pass

# If load failed use the Foursquare API to get the data
if not loaded:
    restaurants, location_restaurants = get_restaurants(latitudes, longitudes)
    
    # Let's persists this in local file system
    with open('restaurants_350.pkl', 'wb') as f:
        pickle.dump(restaurants, f)
    with open('location_restaurants_350.pkl', 'wb') as f:
        pickle.dump(location_restaurants, f)
# Out:
# Obtaining venues around candidate locations: . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . done.

# %%
import numpy as np

print('Total number of restaurants:', len(restaurants))
print('Average number of restaurants in neighborhood:', np.array([len(r) for r in location_restaurants]).mean())
# Out:
# Total number of restaurants: 379
# Average number of restaurants in neighborhood: 2.2335164835164836

# %% [markdown]
# ## Analysis

# %% [markdown]
# Let's perform some basic explanatory data analysis and derive some additional info from our raw data. First let's count the number of restaurants in every area candidate:

# %%
location_restaurants_count = [len(res) for res in location_restaurants]

df_locations['Restaurants in area'] = location_restaurants_count

print('Average number of restaurants in every area with radius=300m:', np.array(location_restaurants_count).mean())

df_locations.head(10)
# Out:
# Average number of restaurants in every area with radius=300m: 2.2335164835164836
#       Address   Latitude  Longitude             X             Y  \
# 0  NO ADDRESS  18.898853  72.809006  7.524044e+06  3.638377e+06
# 1  NO ADDRESS  18.897358  72.812025  7.524644e+06  3.638377e+06
# 2  NO ADDRESS  18.895864  72.815044  7.525244e+06  3.638377e+06
# 3  NO ADDRESS  18.894369  72.818062  7.525844e+06  3.638377e+06
# 4  NO ADDRESS  18.892875  72.821080  7.526444e+06  3.638377e+06
# 5  NO ADDRESS  18.891381  72.824097  7.527044e+06  3.638377e+06
# 6  NO ADDRESS  18.889886  72.827115  7.527644e+06  3.638377e+06
# 7  NO ADDRESS  18.903583  72.805838  7.523144e+06  3.638897e+06
# 8  NO ADDRESS  18.902088  72.808857  7.523744e+06  3.638897e+06
# 9  NO ADDRESS  18.900594  72.811876  7.524344e+06  3.638897e+06
#
#    Distance from center  Restaurants in area
# 0           5992.495307                    0
# 1           5840.376700                    1
# 2           5747.173218                    0
# 3           5715.767665                    0
# 4           5747.173218                    0
# 5           5840.376700                    0
# 6           5992.495307                    0
# 7           5855.766389                    1
# 8           5604.462508                    1
# 9           5408.326913                    0

# %%
df=df_locations[(df_locations['Restaurants in area']==0) & (df_locations['Distance from center']<=1000)].reset_index()
df.drop('index',inplace=True,axis=1)
df
# Out:
#       Address   Latitude  Longitude             X             Y  \
# 0  NO ADDRESS  18.917746  72.834686  7.526444e+06  3.643574e+06
# 1  NO ADDRESS  18.919484  72.837556  7.526744e+06  3.644093e+06
#
#    Distance from center  Restaurants in area
# 0            793.725393                    0
# 1            900.000000                    0

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Taj

# add a red circle marker to represent the Taj
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Taj',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the restaurants as blue circle markers
for lat, lng in zip(df.Latitude, df.Longitude):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Result

# %% [markdown]
# Our analysis shows that there are many restraunts near Taj Hotel and we were mainly concerned about finding best suitable location that is not already crowded with restraunts and is nearest to Taj and very famous 'Gateway of India'. Total number (~91 in our initial area of interest which was 12x12km around Taj), there are large pockets of low restraunt density fairly close to Taj. Highest concentration of restraunts was detected north from Taj, so we found out the neighbourhoods with no restaraunts and distance from taj less than 1km and found out 5 such suitable neighbourhoods.
#
# Result of all these zones containing largest number of potential new restraunt location. Purpose of this analysis was to provide information on areas close to Taj.It is entirely possible that there is a very good reason for small number of restaraunts in any of those areas, reasons which would make them unsuitable for a new restaurant regardless of lack of competition in the area. Recommended zones should therefore be considered only as a starting point for more detailed analysis which could eventually result in location which has not only no nearby competition but also other factors taken into account and all other relevant conditions met.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Purpose of this project was to identify Mumbai areas close to Taj and Gateway of India with low number of restaurants in order to aid stakeholders in narrowing down the search for optimal location for a new restaurant. By calculating restaurant density distribution from Foursquare data we have first identified co-ordinates and neighbourhoods that justify further analysis and then generated extensive collection of locations which satisfy some basic requirements regarding existing nearby restaurants.Final decission on optimal restaurant location will be made by stakeholders based on specific characteristics of neighborhoods and locations in every recommended zone, taking into consideration additional factors like attractiveness of each location (proximity to park or water), levels of noise / proximity to major roads, real estate availability, prices, social and economic dynamics of every neighborhood etc.
